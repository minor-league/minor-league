# %%
# pip install --upgrade pororo
# pip install jupyter
# jupyter notebook --ip='0.0.0.0' --allow-root

# %%
from pororo import Pororo
# Wait...

# %%
###########################################################################
# 1. Summarization : Pororo(task="summarization", model="brainbert.base.ko.summary", lang="ko")

# %%
summarizer = Pororo(task="summarization", model="brainbert.base.ko.summary", lang="ko")

# %%
text = """백영웅전 라이징의 발매가 임박했습니다.
 
백영웅전 라이징 의 아이디어는 킥스타터의 목표를 더 높게 설정하려던 미팅 중 나온 것입니다.
킥스타터를 통한 후원자들의 지원이 백영웅전 프로젝트의 시작이 되었습니다. 이런 식의 프로젝트는 일반 게임 개발과 달리 타이틀 발표부터 실제 출시까지의 기간이 길어지게 됩니다. 특히 RPG가 되면 수년 단위가 되죠.
그 간극을 메울 수 있는 기획 아이디어로 나온 것이 “도우미” 게임 개발이었습니다.
 
다만 처음에는 개발진들이 난색을 표하기도 했습니다.『블러드스테인드: 리추얼 오브 더 나이트』같은 경우에는 도우미 게임으로 방향성이 다르다고는 하지만 같은 액션 게임 장르인『블러드스테인드: 커스 오브 더 문』이 발매된 것은 알고는 있었지만, 커맨드 기반 RPG인 『백영웅전』에 대해서는 한정된 예산으로 어떻게 도우미 게임을 제작할 수 있을지 방향이 보이지 않았습니다.
 
또, 도우미 게임은 백영웅전 본편과는 다른 개발라인을 움직일 필요가 있었습니다만, 그것을 의뢰할 수 있는 회사를 찾을 수 있는가 하는 문제도 있었습니다.
 
그래서 의뢰할 수 있는 개발사 후보로 이름이 오르내린 몇몇 회사 중에 “나츠메 아타리”사가 있었습니다. 개인적으로 신뢰할 수 있는 회사라고 생각했으며, 기획으로 올라온 액션 RPG라는 방향성은 도우미 게임으로서의 조건, 한정된 예산 내에서의 제작가능여부, 한정된 캐릭터로 느낄 수 있는 즐거움이라는 조건에도 부합했습니다.
 
나츠메 아타리와의 협의에서는, RPG의 즐거움인 「건설의 즐거움」 「조금 노력하면 클리어 할 수 있는 목표를 제시해 클리어의 기쁨을 제공」이라고 하는 가치관을 공유할 수 있었습니다. '백영웅전 라이징'을 플레이하는 분들 중에는 커맨드식 RPG를 기대하는 분들이 많다는 점에도 주의를 기울였습니다.
 
'RPG'와 '액션 RPG'는 다른 장르입니다만, 그 차이는 각각의 작품이 지향하는 입장, 목적의 차이로 생겨난 것이고, 근본적으로는 같은 즐거움을 공유하고 있다고 생각합니다.
 
백영웅전 라이징을 즐겨 주시길 바랍니다.
요즘 제게 허락된 몇 안 되는 즐거움은 산책입니다. 그 산책에 한 때의 기쁨을 더해 주는 것은 계절을 느끼게 하는 벚꽃이네요.
""" # https://page.onstove.com/indie/global/view/8487091

summarizer([text])
# Out:
# ["백영웅전 라이징의 발매가 임박했습니다. 그 간극을 메울 수 있는 기획 아이디어로 나온 것이 “도우미” 게임 개발이었습니다. 'RPG'와 '액션 RPG'는 다른 장르입니다만, 그 차이는 각각의 작품이 지향하는 입장, 목적의 차이로 생겨난 것이고, 근본적으로는 같은 즐거움을 공유하고 있다고 생각합니다."]

# %%
###########################################################################
# 2. Machine Reading Comprehension(기계 독해) : Pororo(task="mrc", lang="ko")

# %%
mrc = Pororo(task="mrc", lang="ko")

# %%
text = """ 안녕하세요 스토브인디 유저 여러분!  

스토브인디 한글화담당자 입니다.


여러 한글화 파트너들과 함께, 스토브인디는 계속 게임들을 한글화하고 있습니다 
현황판은 매주 화요일 오전에 업데이트됩니다.


한글화는 다음의 3가지 과정을 통해 출시됩니다:
01. 번역 
02. 검수 
03. 출시 준비 
출시 준비 중인 게임은 모든 번역이 완료되어 출시만 기다리고 있어요! 
(각 게임들의 이미지나 타이틀을 클릭하시면 게임 소개 페이지로 연결됩니다.)

한 게임이 출시되기까지는 번역, 검수, LQA까지 꽤 많은 시간과 노력이 필요합니다 
조금 시간이 걸리더라도 퀄리티 좋은 한글화 게임들을 보여드리기 위한 절차들이니, 조금만 기다려주세요...!!

스토브에서 번역한 게임 중 오역, 오탈자, 문맥상 부드럽지 못한 부분을 발견하셨다면 알려주세요!
개발사로 전달해 빠르게 수정할 수 있도록 하겠습니다.

출시일은 개발사 사정에 의해 변동될 수 있습니다.

여러분의 성원에 힘입어 한글화 파트너 분들이 많이 모여주셨습니다!
안타깝지만 신규 파트너 모집은 잠시 중단됩니다.

새로운 모집 기간을 기다려주세요!
""" # https://page.onstove.com/indie/global/view/8486831

print(mrc("언제 업데이트?", text))
print(mrc("한글화 과정?", text))
print(mrc("파트너 모집 언제까지해?", text))
# Out:
# ('매주 화요일 오전', (43, 46))
# ('3가지 과정을 통해 출시됩니다: 01. 번역 02. 검수 03. 출시 준비 출시 준비 중인 게임은 모든 번역이 완료되어 출시만 기다리고 있어요! (각 게임들의 이미지나 타이틀을 클릭하시면 게임 소개 페이지로 연결됩니다.) 한 게임이 출시되기까지는 번역, 검수, LQA', (53, 111))
# ('잠시 중단', (212, 214))

# %%
text = """ 
플레이어의 매 순간 순간의 선택이 브란테 경의 삶을 관장한다!
선택에 따라 그는 판사, 이단심문관, 
혹은 기존의 질서를 뒤엎는 혁명가까지도 될 수 있습니다.
당신의 브란테 경은 어떤 인물로 성장하게 될까요?
출시 날짜: 2021년 3월
개발사: Sever
인기 태그: RPG, 선택의 중요성, 풍부한 스토리
스토브인디 한글화 관련 정보: 스토브인디에서 전면 한글화를 진행중입니다. 
The Life and Suffering of Sir Brante (브란테 경의 삶과 고난)
게임 특징 
브란테 경의 삶과 고난은 태어날 때부터 운명이 정해져 있고, 신들이 실제 존재하며 인간의 운명을 관장하는 암울한 세계에서 펼쳐지는 스토리 중심의 RPG입니다.
인생의 여정을 시작해 운명의 개척자로 거듭나보세요. 여러분은 판사, 이단심문관, 혹은 기존의 질서를 뒤엎는 혁명가가 될 수 있을까요? 모두 여러분의 선택에 달려 있습니다! 
평민으로 태어나 아무런 권리와 작위도 없이 가장 힘든 운명을 짊어지게 된 여러분은 운명을 거스르고 브란테 가문의 유산을 이어갈 정당한 후계자로 거듭나기 위해 기존의 관습과 편견을 이겨내야만 합니다. 출생부터 진정한 죽음에 이르기까지, 인생의 여정을 거치며 엄청난 변화와 역경을 견뎌내고 매사 어려운 일에도 현명한 판단을 내려야 합니다. 여러분의 선택은 주인공뿐 아니라 가족과 사랑하는 이들에게도 영향을 주고, 심지어는 제국의 근간을 뒤흔들 수도 있습니다.
변화의 기로:  제국에서 시민들의 삶은 신분에 따라 정해집니다. 필멸자들의 운명은 쌍둥이 신들이 만든 이러한 세상의 진리에 따라 움직이고 있습니다. 귀족들은 다른 이들을 이끌며 군림하고, 성직자들은 사람들을 참된 길로 인도하며, 평민들은 제국의 영광을 위해 고된 삶을 살아갑니다. 아무런 의문도 가지지 않은 채 운명을 받아들일 것인지, 아니며 온 힘을 다해 세상을 지배하는 우주적 질서를 바꿀 것인지, 선택은 여러분의 몫입니다.
당신의 선택이 이야기를 만듭니다: 게임은 챕터별로 나누어져 있으며, 플레이어의 행동과 습득한 기술 그리고 고유한 스토리라인을 형성하는 여러 개의 동시다발적 상황을 모두 기록합니다. 모든 선택에는 결과가 뒤따르며, 이에 대한 책임은 모두 여러분에게 있습니다. 가문과 사랑하는 이들을 보호하기 위해, 황제를 받들며 부귀영화를 누리기 위해, 아니면 세상을 여러분이 원하는 대로 변화시키기 위해… 여러분이 원하는 삶에 도전해보세요. 단, 자만과 야망을 가진 자들은 항상 주의해야 합니다.
인생을 건 싸움 : 브란테 경은 한 명의 인간에 불과하지만, 그에게 불가능은 없습니다. 운명이 선사하는 모든 역경을 이겨내고 세상을 지배하는 규칙을 새롭게 써 내려가세요! 판단력, 감수성, 인내력 등의 특성을 레벨업해 캐릭터를 성장시키세요. 게임 초반에 습득한 주인공의 기술은 모두 캐릭터의 성격과 세계관, 타인과의 관계는 물론, 궁극적으로는 새로운 재능과 스토리라인에 영향을 줍니다.
나만의 길을 찾아서 : 첫 회차를 플레이하는 데는 20시간 이상이 걸릴 수 있습니다. 첫 회차 이후에도, 스토리에 영향을 주는 분기가 매우 다양하게 마련되어 있어, 매번 플레이할 때마다 새로운 경험을 선사합니다. 귀족 판사가 되거나, 이단 심문관이 되거나, 비밀 집단의 일원으로서 혁명을 계획하거나, 아니면 전혀 다른 목표를 위해 노력해보세요. 용감히 도전한다면 운명은 여러분의 의지에 굴복할 것입니다!
현재 그리고 미래: 브란테 경의 삶과 고난에서는 몇 번의 부활이 가능합니다. 덕분에 캐릭터가 죽어도 경험은 사라지지 않으므로, 플레이어는 과거의 행적을 돌아보며 앞으로의 전략을 수정할 수 있습니다. 삶과 죽음을 모두 내 손으로 관장하며, 죽음과 부활의 순환을 통해 모든 것을 건 모험에 도전하세요!
""" # https://page.onstove.com/indie/global/view/8401416

print(mrc("출시 언제했어?", text))
print(mrc("장르 뭐야?", text))
print(mrc("무슨 게임이야?", text))
# Out:
# ('2021년 3월', (61, 65))
# ('RPG', (72, 74))
# ('The Life and Suffering of Sir Brante (브란테 경의 삶과 고난)', (102, 124))

# %%
###########################################################################
# 3. Sentiment Analysis : Pororo(task="sentiment", model="brainbert.base.ko.nsmc", lang="ko")

# %%
sa = Pororo(task="sentiment", model="brainbert.base.ko.nsmc", lang="ko")

# %%
print(sa("이거 트레일러 한글 더빙도 있던데.. 비교해서 같이  올려주세요..."))
print(sa("이런거 좋음"))
print(sa("""게임 컨셉이랑 일러스트, 그래픽이 너무 취향저격이라 재밌게 했음 
         도트그래픽이랑 움직이는 방식이 약간 레인월드 생각나기도 했네요 ㅋㅋㅋㅋ 할인받아서 사면 충분히 돈값 하는 게임!"""))
# https://indie.onstove.com/ko/games/920
# Out:
# Positive
# Positive
# Positive

# %%
print(sa("1인칭 스릴러 영화 같은 분위기.... 뚝뚝~ 끊어져 다른 공간으로 이어지는 화면 구성... 초반엔 많이 지루할 수 있음."))
# https://indie.onstove.com/ko/games/566
# Out:
# Negative

# %%
###########################################################################
# 4. Zero-shot Topic:  Pororo(task="zero-topic")

# %%
zsl = Pororo(task="zero-topic")

# %%
text = """
미소녀 K와 개성 넘치는 보스들이 펼치는 액션을 만나보세요!
다년간의 액션 게임 개발 노하우를 살린, 역동적인 3D 액션과 뛰어난 타격감, 박자감 있는 액션을 제공합니다. 
3D 액션 카메라는 동적으로 전환되어 역동적인 전투 경험을 전달합니다.
""" # https://indie.onstove.com/ko/games/417
zsl(text,["여캐", "잔인한", "사운드", "그래픽", "남캐", "힐링"])
# Out:
# {'여캐': 50.84, '잔인한': 37.44, '사운드': 37.44, '그래픽': 67.4, '남캐': 33.6, '힐링': 45.65}

# %%
text = """
게임 「30일」은 자살 예방을 소재로 한 멀티 엔딩 스토리 어드벤처 게임입니다.
게임을 시작하면 30일 뒤 ‘최설아’의 죽음을 알리는 사망진단서가 나타납니다.
당신은 주어진 30일 동안 설아가 거주하는 로얄고시원의 총무로 플레이하면서, 
죽음과 관련된 단서를 찾고 다양한 선택지를 마주하게 됩니다.
하루하루 스토리를 진행하며 사망진단서에 예정된 설아의 죽음을 바꿀 수 있습니다.
""" 

zsl(text,["스토리", "액션", "시뮬레이션"])
# Out:
# {'스토리': 70.18, '액션': 29.29, '시뮬레이션': 56.44}

# %%
###########################################################################
# 5. Semantic Textual Similarity

# %%
sts = Pororo(task="similarity", lang="ko")

# %%
print(sts("스토리 있는 게임이 좋아", "선호하는 게임은 스토리 있는 게임"))
# Out:
# 0.884

# %%
# ###########################################################################
# 6. Word Embedding

# %%
word2vec = Pororo(task="word2vec", lang="ko")

# %%
word2vec.find_similar_words("메이플")
# Out:
# OrderedDict([('메이플 (word)',
#               ['화이트 (word)',
#                '애플파이 (word)',
#                '파밍 (word)',
#                '쿠키런 (video game)',
#                '트레져 (word)']),
#              ('메이플 (소프트웨어) (computer algebra system;programming language;data analysis software;interpreted language)',
#               ['Scilab (numerical software;programming language)',
#                'E4X (misc)',
#                '분류:수치 프로그래밍 언어 (Wikimedia category)',
#                'Boost (free software;software library;Software Freedom Conservancy)',
#                '분류:4세대 프로그래밍 언어 (Wikimedia category)'])])

# %%
word2vec("배틀그라운드")
# Out:
# OrderedDict([('배틀그라운드 (Wikimedia disambiguation page)',
#               tensor([-0.6715, -0.4152, -0.1672, -0.4887, -0.0764,  0.0877, -0.0276, -0.1049,
#                       -0.0519, -0.3239,  0.1239,  0.0022, -0.6904,  0.5917,  0.1895,  0.5046,
#                        0.1851,  0.7083,  0.0802,  0.0196, -0.1937,  0.7167,  0.2032,  0.0079,
#                       -0.5705, -0.2840, -0.4953, -0.1373, -0.0404,  0.3486,  0.0366,  0.7481,
#                        0.2788,  0.0437, -0.3493, -0.7935,  0.2342,  0.1294, -0.0543,  0.3339,
#                        0.3953, -0.7834,  0.1828,  0.2150,  0.3202,  0.2601,  0.2567,  0.1834,
#                       -0.2504, -0.3714, -0.2324, -0.9779, -0.7894,  0.3021, -0.3702,  0.6856,
#                       -0.3715,  0.0155,  0.4287, -0.3612, -0.5257, -0.2771, -0.4895, -0.1575,
#                       -0.1270, -0.6231, -0.7470, -0.6425,  0.7947, -0.0270, -1.3635, -0.4534,
# ...

# %%
###########################################################################
# 7. Sentence Embedding

# %%
se = Pororo(task="sentence_embedding", lang="ko")
# Out:
# 100% [....................................................] 408578554 / 408578554
# 100% [..........................................................] 534163 / 534163

# %%
query = "고양이가 창 밖을 바라본다"
cands = [
    "고양이가 카메라를 켠다",
    "남자와 여자가 걷고 있다",
    "고양이가 개를 만지려 하고 있다",
    "두 마리의 고양이가 창문을 보고 있다",
    "테이블 위에 앉아 있는 고양이가 창밖을 내다보고 있다",
    "창밖을 내다보는 고양이"
 ]
se.find_similar_sentences(query, cands)
# Out:
# {'query': '고양이가 창 밖을 바라본다',
#  'ranking': [(5, '창밖을 내다보는 고양이', 0.93),
#   (4, '테이블 위에 앉아 있는 고양이가 창밖을 내다보고 있다', 0.91),
#   (3, '두 마리의 고양이가 창문을 보고 있다', 0.78),
#   (0, '고양이가 카메라를 켠다', 0.74),
#   (2, '고양이가 개를 만지려 하고 있다', 0.41)]}

# %%
#####################################################################
# 8. Review Scoring

# %%
review = Pororo(task="review", lang="ko")
# Out:
# 100% [....................................................] 205784022 / 205784022

# %%
print(review("흠 모르겠다모르겠어"))
print(review("단순하고 재밌는데 처음에 어떻게해야할지 모르겠어요 설명같은걸 넣어주시면 더좋을거같아요"))
review("말그대로 어린이용 코딩 게임이라는 느낌이 나네요 지금은 심각하게 단순한 상태지만 개선의 여지가 있는게 좋다고 생각합니다")
# Out:
# 2.59
# 4.18
# 2.67

# %%
#####################################################################
# 9. Named Entity Recognition

# %%
ner = Pororo(task="ner", lang="ko")

# %%
print(ner("정가 4900원에 3000원 쿠폰으로 할인받아 1900원에 구매하였습니다. \
            실 플레이 타임은 1시간도 안됩니다."))
print(ner("이런 류의 게임을 좋아하긴 하는데. 많이 실망했습니다."))
print(ner("소재는 좋았습니다.그렇지만 방향키를 작동해 NPC와 상호작용하는 \
    방식이 지속될수록 피곤했고,진짜 중요한거는. 분량이 진짜 적습니다."))
print(ner("짧고 간결한 동화책을 읽은 듯한 느낌이며 비주얼 노벨이라고 생각하시면 됩니다."))
# https://indie.onstove.com/ko/games/426

ner("손흥민은 28세의 183 센티미터, 77 킬로그램이며, 현재 주급은 약 3억 원이다.")
# Out:
# [('정가', 'O'), (' ', 'O'), ('4900원', 'QUANTITY'), ('에', 'O'), (' ', 'O'), ('3000원', 'QUANTITY'), (' ', 'O'), ('쿠폰으로', 'O'), (' ', 'O'), ('할인받아', 'O'), (' ', 'O'), ('1900원', 'QUANTITY'), ('에', 'O'), (' ', 'O'), ('구매하였습니다.', 'O'), (' ', 'O'), ('실', 'O'), (' ', 'O'), ('플레이', 'O'), (' ', 'O'), ('타임은', 'O'), (' ', 'O'), ('1시간', 'TIME'), ('도', 'O'), (' ', 'O'), ('안됩니다.', 'O')]
# [('이런', 'O'), (' ', 'O'), ('류의', 'O'), (' ', 'O'), ('게임을', 'O'), (' ', 'O'), ('좋아하긴', 'O'), (' ', 'O'), ('하는데.', 'O'), (' ', 'O'), ('많이', 'O'), (' ', 'O'), ('실망했습니다.', 'O')]
# [('소재는', 'O'), (' ', 'O'), ('좋았습니다.', 'O'), (' ', 'O'), ('그렇지만', 'O'), (' ', 'O'), ('방향키를', 'O'), (' ', 'O'), ('작동해', 'O'), (' ', 'O'), ('NPC', 'CIVILIZATION'), ('와', 'O'), (' ', 'O'), ('상호작용하는', 'O'), (' ', 'O'), ('방식이', 'O'), (' ', 'O'), ('지속될수록', 'O'), (' ', 'O'), ('피곤했고,진짜', 'O'), (' ', 'O'), ('중요한거는.', 'O'), (' ', 'O'), ('분량이', 'O'), (' ', 'O'), ('진짜', 'O'), (' ', 'O'), ('적습니다.', 'O')]
# ...
